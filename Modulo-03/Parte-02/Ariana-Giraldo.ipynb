# %%
# !wget 'https://datosabiertos.gob.pe/sites/default/files/Datos_abiertos_admision_2021_1_2024_1.csv' -O datos-uni-agosto-25.csv
# Out:
# --2025-08-06 01:03:01--  https://datosabiertos.gob.pe/sites/default/files/Datos_abiertos_admision_2021_1_2024_1.csv
# Resolving datosabiertos.gob.pe (datosabiertos.gob.pe)... 119.8.199.203
# Connecting to datosabiertos.gob.pe (datosabiertos.gob.pe)|119.8.199.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13218729 (13M) [application/octet-stream]
# Saving to: ‘datos-uni-agosto-25.csv’
#
# datos-uni-agosto-25 100%[===================>]  12.61M  10.0MB/s    in 1.3s
#
# 2025-08-06 01:03:03 (10.0 MB/s) - ‘datos-uni-agosto-25.csv’ saved [13218729/13218729]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/datos-uni-agosto-25.csv')

# %%
df.head(8)
df.tail(6)
df.sample(6)
# Out:
#                                                   IDHASH  \
# 31022  C8655AEFB074103C56D97AD81AEE7FD0856E563AFCB361...
# 34991  39E544DC4BDDDB638F5AE4E473563FC5F852AB00CE1019...
# 10647  F8B26EF18617930AEAB40C3A821683DF884A422896A446...
# 31341  5B38ABDB970534895F43DEE91E476710374B7ABFF74222...
# 41771  F0475979E44A197DCE9183F0CA131F93808FE2890BB527...
# 11069  E4512EAD0CB143EFF2BA94042C51E21D630988FA0359F9...
#
#                                 COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 31022                 AUGUSTO B. LEGUIA         LIMA                   LIMA
# 34991                   COAR LAMBAYEQUE   LAMBAYEQUE               CHICLAYO
# 10647  6093 CORONEL JUAN VALER SANDOVAL         LIMA                   LIMA
# 31341                    TRILCE DE ROMA         LIMA                   LIMA
# 41771      CORAZONES MARIANOS DEL NORTE         LIMA                   LIMA
# 11069                     5098 KUMAMOTO       CALLAO  PROV CONST DEL CALLAO
#
# ...

# %%
df.columns
# Out:
# Index(['IDHASH', 'COLEGIO', 'COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_DIST',
#        'COLEGIO_PAIS', 'COLEGIO_ANIO_EGRESO', 'ESPECIALIDAD', 'ANIO_POSTULA',
#        'CICLO_POSTULA', 'DOMICILIO_DEPA', 'DOMICILIO_PROV', 'DOMICILIO_DIST',
#        'ANIO_NACIMIENTO', 'NACIMIENTO_PAIS', 'NACIMIENTO_DEPA',
#        'NACIMIENTO_PROV', 'NACIMIENTO_DIST', 'SEXO', 'CALIF_FINAL', 'INGRESO',
#        'MODALIDAD'],
#       dtype='object')

# %%
df2 = df[df['DOMICILIO_DEPA']=='LIMA']
df2
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 5      3A060265D9E508F256DC9E1881ED163F8D2FB192D04095...
# ...                                                  ...
# 42508  5E35AC40B02D7C8E47EA088641791B7010FCCDD958B948...
# 42509  CDB1535A398BA8A4465DD7C10578DE7F6835513112F9D5...
# 42510  B72BBA63F1DD27BB1619F02203A83B65CF8C139797E800...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                                 COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0                 LA DIVINA PROVIDENCIA         LIMA         LIMA
# 2            0113 DANIEL ALOMIAS ROBLES         LIMA         LIMA
# 3               SEBASTIAN SALAZAR BONDY         LIMA         LIMA
# ...

# %%
df3 = df[df['SEXO']=='FEMENINO'].value_counts()
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2936212987.py in <cell line: 0>()
# ----> 1 df3 = df[df['SEXO']=='FEMENINO'].value_counts()
#       2 df3
#
# NameError: name 'df' is not defined

# %% [markdown]
# Cuantas modalidades de ingreso hay?

# %%
df['MODALIDAD'].value_counts()
# Out:
# MODALIDAD
# ORDINARIO                                                                                            24054
# INGRESO ESCOLAR NACIONAL                                                                              7245
# EXTRAORDINARIO 2 – INGRESO DIRECTO CEPRE                                                              3666
# EXTRAORDINARIO INGRESO DIRECTO CEPRE-UNI                                                              3178
# EXTRAORDINARIO INGRESO DIRECTO CEPRE-UNI O CEPRE-UNI INTENSIVO                                        1405
# EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE                                                                930
# TALENTO BECA 18                                                                                        397
# EXTRAORDINARIO - DOS PRIMEROS ALUMNOS                                                                  298
# EXTRAORDINARIO 1 - DOS PRIMEROS ALUMNOS                                                                279
# ...

# %% [markdown]
# Cual es la calificación media de los ingresantes?

# %%
df[df['INGRESO']=='SI']['CALIF_FINAL'].median()
# Out:
# 12.832

# %%
df[df['CALIF_FINAL']==12.832]
# Out:
#                                                   IDHASH  \
# 9994   753774A61FAE7C83D89E532AAA1258E094DDBC95C71F1B...
# 20797  9F761A03AA70D60A97FDDF2880C1D40D9BC33A8A184895...
# 38573  07B485D5CE2DF8FB78A2F4374D2785D7BEF6A72C997345...
# 41115  6AC3135FC2860526F847E05A8343FB46594CA62DFEDF4F...
#
#                                COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 9994               ENRIQUE MILLA OCHOA         LIMA                   LIMA
# 20797             1278 MIXTO LA MOLINA         LIMA                   LIMA
# 38573  5122 JOSE ANDRES RAZURI ESTEVEZ       CALLAO  PROV CONST DEL CALLAO
# 41115               6048 JORGE BASADRE         LIMA                   LIMA
#
#             COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 9994          LOS OLIVOS          NaN                 2016
# 20797          LA MOLINA          NaN                 2020
# 38573         VENTANILLA          NaN                 2018
# 41115  VILLA EL SALVADOR         PERÚ                 2018
#
# ...

# %% [markdown]
# Cual es la moda de los años de nacimient?

# %%
df['ANIO_NACIMIENTO'].mode()
# Out:
# 0    2004
# Name: ANIO_NACIMIENTO, dtype: int64

# %%
Cual es el puntaje maximo para los que dieron el examen ordinario?

# %%
df[df['MODALIDAD']=='ORDINARIO']['CALIF_FINAL'].max()
# Out:
# 18.895

# %%
DEPARTAMENTOS_URBANOS = ['CALLAO', 'LIMA', 'TUMBES', 'ICA', 'AREQUIPA', 'TACNA', 'LAMBAYEQUE']

# %%
df['ZONA'] = df['DOMICILIO_DEPA'].apply(lambda x: 'URBANO' if x in DEPARTAMENTOS_URBANOS else 'RURAL')

# %%
df.sample(8)
# Out:
#                                                   IDHASH  \
# 21449  58AAD662BAD614E3CE52F20AF7A3D1AD927CF301C54E4A...
# 3445   C0984409E075863F0D11C8184BF2DB3C15A26C6FCA6EE0...
# 22808  5CA2C224B4C28D624B4FFB6E7BCD707AD68395B3B00653...
# 21650  B66073E3AC31D2F854FAA34E3FE49C280D0C23B4A05AAE...
# 14069  B3FD76DFF262A7F26D66F0BF0E2572AB2ACD472D197A82...
# 27878  81A708503B34E2BBABE7E310EDDA74AAC60331486E62AC...
# 489    C02CC99E4ABD600783B948B45C0F60858F0E7F2CF5572F...
# 7971   13BA14AACD959EBEF4EC6930EC9B50A47473B1CD5E2AB7...
#
#                                             COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 21449                          JESUS EL BUEN PASTOR         LIMA         LIMA
# 3445                           7213 PERUANO JAPONES         LIMA         LIMA
# 22808                                     ALFAGROUP         LIMA         LIMA
# 21650                                2026 SAN DIEGO         LIMA         LIMA
# ...

# %%
df['ZONA'].value_counts()
# Out:
# ZONA
# URBANO    37510
# RURAL      5006
# Name: count, dtype: int64

# %%
ADMITIDOS_POR_ZONA = df[df['INGRESO']=='SI']['ZONA'].value_counts()
NO_ADMITIDOS_POR_ZONA = df[df['INGRESO']=='NO']['ZONA'].value_counts()

# %%
sns.barplot(x=NO_ADMITIDOS_POR_ZONA.index, y=NO_ADMITIDOS_POR_ZONA.values , label = 'No ingresaron', color='red')
sns.barplot(x=ADMITIDOS_POR_ZONA.index, y=ADMITIDOS_POR_ZONA.values , label = 'Ingresaron', color='blue')
plt.ylabel('Numero de postulantes')
plt.show()

# %%
LIMA_SUR = ['VILLA EL SALVADOR', 'VILLA MARIA DEL TRIUNFO', 'CHORRILLOS', 'LURIN', 'PACHACAMAC', 'SAN JUAN DE MIRAFLORES', 'SANTIAGO DE SURCO', 'PUNTA HERMOSA', 'PUNTA NEGRA', 'SAN BARTOLO', 'PUCUSANA', 'SANTA MARIA DEL MAR']
LIMA_NORTE = ['ANCON', 'INDEPENDENCIA','CARABAYLLO', 'COMAS','LOS OLIVOS','PUENTE PIEDRA','SAN MARTIN DE PORRES', 'SANTA ROSA']
LIMA_CENTRO = ['LIMA', 'BRENA', 'JESUS MARIA','LINCE', 'BARRANCO','SAN ISIDRO','SAN MIGUEL','MAGDALENA DEL MAR','PUEBLO LIBRE','SAN BORJA','RIMAC','LA VICTORIA','MIRAFLORES','CHORRILLOS']

df2['SECTOR'] = df['NACIMIENTO_PROV'].apply(lambda x: 'SUR' if x in LIMA_SUR else ('NORTE' if x in LIMA_NORTE else ('CENTRO' if x in LIMA_CENTRO else 'OTRO')))
df2
# Out:
# /tmp/ipython-input-1521394017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['SECTOR'] = df['NACIMIENTO_PROV'].apply(lambda x: 'SUR' if x in LIMA_SUR else ('NORTE' if x in LIMA_NORTE else ('CENTRO' if x in LIMA_CENTRO else 'OTRO')))
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 5      3A060265D9E508F256DC9E1881ED163F8D2FB192D04095...
# ...                                                  ...
# 42508  5E35AC40B02D7C8E47EA088641791B7010FCCDD958B948...
# ...

# %%
df2['SECTOR'] = df['NACIMIENTO_PROV'].apply(lambda x: 'SUR' if x in LIMA_SUR else ('NORTE' if x in LIMA_NORTE else ('CENTRO' if x in LIMA_CENTRO else 'OTRO')))
df2
# Out:
# /tmp/ipython-input-3439235064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['SECTOR'] = df['NACIMIENTO_PROV'].apply(lambda x: 'SUR' if x in LIMA_SUR else ('NORTE' if x in LIMA_NORTE else ('CENTRO' if x in LIMA_CENTRO else 'OTRO')))
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 5      3A060265D9E508F256DC9E1881ED163F8D2FB192D04095...
# ...                                                  ...
# 42508  5E35AC40B02D7C8E47EA088641791B7010FCCDD958B948...
# ...

# %%
df2
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# 5      3A060265D9E508F256DC9E1881ED163F8D2FB192D04095...
# ...                                                  ...
# 42508  5E35AC40B02D7C8E47EA088641791B7010FCCDD958B948...
# 42509  CDB1535A398BA8A4465DD7C10578DE7F6835513112F9D5...
# 42510  B72BBA63F1DD27BB1619F02203A83B65CF8C139797E800...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                                 COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0                 LA DIVINA PROVIDENCIA         LIMA         LIMA
# 2            0113 DANIEL ALOMIAS ROBLES         LIMA         LIMA
# 3               SEBASTIAN SALAZAR BONDY         LIMA         LIMA
# ...

# %%
ADMITIDOS_POR_SECTOR = df[df['INGRESO']=='SI']['SECTOR'].value_counts()
NO_ADMITIDOS_POR_SECTOR = df[df['INGRESO']=='NO']['SECTOR'].value_counts()

# %%
sns.barplot(x=NO_ADMITIDOS_POR_SECTOR.index, y=NO_ADMITIDOS_POR_SECTOR.values , label = 'No ingresaron', color='red')
sns.barplot(x=ADMITIDOS_POR_SECTOR.index, y=ADMITIDOS_POR_SECTOR.values , label = 'Ingresaron', color='blue')
plt.ylabel('Numero de postulantes por sector')
plt.show()

# %%
df['SEXO'].value_counts()
# Out:
# SEXO
# MASCULINO    32419
# FEMENINO     10097
# Name: count, dtype: int64

# %%
ADMITIDOS_POR_SEXO = df[df['INGRESO']=='SI']['SEXO'].value_counts()
NO_ADMITIDOS_POR_SEXO = df[df['INGRESO']=='NO']['SEXO'].value_counts()

# %%
sns.barplot(x=NO_ADMITIDOS_POR_SEXO.index, y=NO_ADMITIDOS_POR_SEXO.values , label = 'No ingresaron', color='red')
sns.barplot(x=ADMITIDOS_POR_SEXO.index, y=ADMITIDOS_POR_SEXO.values , label = 'Ingresaron', color='blue')
plt.ylabel('Numero de postulantes por sexo')
plt.show()

# %%
REG_1 = ['LIMA', 'AREQUIPA','ANCASH', 'TUMBES','PIURA','LAMBAYEQUE','LA LIBERTAD', 'ICA','MOQUEGUA','TACNA']
REG_2 = ['CAJAMARCA', 'PUNO','HUANUCO', 'PASCO','JUNIN','HUANCABELICA','AYACUCHO', 'APURIMAC','CUZCO']
REG_3 = ['AMAZONAS', 'LORETO','UCAYALI', 'MADRE DE DIOS','SAN MARTIN']

# %%
REG_1 = ['LIMA', 'AREQUIPA','ANCASH', 'TUMBES','PIURA','LAMBAYEQUE','LA LIBERTAD', 'ICA','MOQUEGUA','TACNA']
REG_2 = ['CAJAMARCA', 'PUNO','HUANUCO', 'PASCO','JUNIN','HUANCABELICA','AYACUCHO', 'APURIMAC','CUZCO']
REG_3 = ['AMAZONAS', 'LORETO','UCAYALI', 'MADRE DE DIOS','SAN MARTIN']

df['REGIONES_GEO'] = df['NACIMIENTO_DEPA'].apply(lambda x: 'COSTA' if x in REG_1 else ('SIERRA' if x in REG_2 else ('SELVA' if x in REG_3 else 'OTRO')))

# %%
df
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# ...

# %%
ADMITIDOS_POR_REGION = df[df['INGRESO']=='SI']['REGIONES_GEO'].value_counts()
NO_ADMITIDOS_POR_REGION = df[df['INGRESO']=='NO']['REGIONES_GEO'].value_counts()

# %%
sns.barplot(x=NO_ADMITIDOS_POR_REGION.index, y=NO_ADMITIDOS_POR_REGION.values , label = 'No ingresaron', color='red')
sns.barplot(x=ADMITIDOS_POR_REGION.index, y=ADMITIDOS_POR_REGION.values , label = 'Ingresaron', color='blue')
plt.ylabel('Numero de postulantes')
plt.show()
